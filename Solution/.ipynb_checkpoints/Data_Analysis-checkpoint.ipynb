# %% [markdown]
# # Data Analysis
#
#
# Gain some insight into the dataset using Pandas, Numpy and Scikit Learn

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np

DATASET_PATH = "../Eingabedaten/"
GAS_PRICES = "../Eingabedaten/Benzinpreise/"

gas_stations_with_prices_id_list = [int(os.path.splitext(os.path.basename(os.path.join(GAS_PRICES, f)))[0]) for f in os.listdir(os.path.join(GAS_PRICES)) if os.path.isfile(os.path.join(GAS_PRICES, f))]

gas_stations = pd.DataFrame()

def load_gas_station_data(data_location=DATASET_PATH):
    gas_stations = os.path.join(data_location, "Tankstellen.csv")
    return pd.read_csv(gas_stations, sep=";", names=["id", "name", "brand", "street", "house_number", "zip_code", "city", "latitude", "longitude"])


def load_historic_prices(gas_station_id, data_location=DATASET_PATH):
    path = data_location + "Benzinpreise/{}.csv".format(gas_station_id)
    historic_prices = os.path.join(path)
    return pd.read_csv(historic_prices, sep=";", header=None)

def remove_gas_stations_without_prices(gas_stations):
    gas_stations = gas_stations[gas_stations['id'].isin(gas_stations_with_prices_id_list)]
    return gas_stations

# %%
gas_stations = load_gas_station_data()
remove_gas_stations_without_prices(gas_stations)
# Out:
#           id                                         name  \
# 0          1                              star Tankstelle
# 1          2                              Esso Tankstelle
# 2          3                                  SYLT, TRIFT
# 3          4                             DEXX-Station 188
# 5          6                              Aral Tankstelle
# 7          8                            ELAN Suederluegum
# 8          9  OIL! tank & go Automatentankstelle Ladelund
# 9         10                              AVIA Tankstelle
# 10        11                   OIL! Tankstelle Glücksburg
# 11        12                              star Tankstelle
# 12        13                     team Tankautomat Medelby
# 13        14                    OIL! Tankstelle Flensburg
# 14        15                    OIL! Tankstelle Flensburg
# 15        16                     FLENSBURG, MUERWIKER STR
# 16        17                                Martin Kriese
# 17        18                    FLENSBURG, HARRISLEER STR
# 18        19             Flensburg (24944), Schottweg  96
# 19        20                           CLASSIC Langballig
# 20        21                              Aral Tankstelle
# 21        22                               WIKING FL-Nord
# 22        23                           Poetzsch TankTreff
# 23        24                      team Tankstelle Niebüll
# 24        25                       bft-willer Station 158
# 25        26                                   Tankstelle
# 26        27                                ELAN NIEBUELL
# 27        28                              Aral Tankstelle
# 28        29                              star Tankstelle
# 29        30                         HANDEWITT, AN DER B.
# 30        31                    FLENSBURG, FRIESISCHE STR
# 31        32  team Tankstelle Handewitt-Scandinavian Park
# ...      ...                                          ...
# 15196  15197                              Esso Tankstelle
# 15197  15198                             Autoservice GmbH
# 15198  15199                              Esso Tankstelle
# 15199  15200                     C+C Oberallgäu Blaichach
# 15200  15201                              Aral Tankstelle
# 15201  15202                           MOWAG / Tankpool24
# 15202  15203                     Farchant Hauptstrasse 10
# 15203  15204              SB Tankstelle Iller Park Rieden
# 15204  15205                              Aral Tankstelle
# 15205  15206                          Kaufmarkt Sonthofen
# 15206  15207                 BayWa Tankstelle Sonthofen I
# 15207  15208                BayWa Tankstelle Sonthofen II
# 15208  15209                              Esso Tankstelle
# 15209  15210              BK- Tankstelle Frank Szinek GbR
# 15210  15211                   Sb-Tankstelle & Autowäsche
# 15211  15212                  SONTHOFEN, OBERSTDORFER STR
# 15212  15213                                 AVIA Station
# 15213  15214                              Aral Tankstelle
# 15214  15215              GARMISCH-PARTENK. - BURGSTR. 16
# 15215  15216    Garmisch-Partenkirchen Zugspitzstrasse 42
# 15216  15217                              Esso Tankstelle
# 15217  15218                 GARMISCH PARTENK., HAUPTSTR.
# 15218  15219                         KLAIS - HAUPTSTR. 18
# 15219  15220                        Fischen Berger Weg 15
# 15220  15221          MITTENWALD - PARTENKIRCHNER STRASSE
# 15221  15222                   V-Markt Fischen/Langenwang
# 15222  15223                              Esso Tankstelle
# 15223  15224          OBERSTDORF - SONTHOFENER STRASSE 16
# 15224  15225                    MITTENWALD, AM BRUNNSTEIN
# 15225  15226                              Esso Tankstelle
#
#                                 brand                  street house_number  \
# 0                                STAR         Listlandstrasse           16
# 1                                ESSO                 TRIFT 2
# 2                               Shell                 TRIFT 7          NaN
# 3                                DEXX               Dorfstr.            19
# 5                                ARAL     Keitumer Landstraße          NaN
# 7                                ELAN               HAUPTSTR.            4
# 8                                OIL!           Dorfstraße 24          NaN
# 9                    Freie Tankstelle              An der B 5          NaN
# 10                               OIL!   Flensburger Str. 15 B          NaN
# 11                               STAR            Fördestrasse           80
# 12                               team               Hauptstr.           36
# 13                               OIL!      Apenrader Str. 109          NaN
# 14                               OIL!          Osterallee 207          NaN
# 15                              Shell      MUERWIKER STR. 120          NaN
# 16                              SHELL                Kielseng            1
# 17                              Shell      HARRISLEER STR. 98          NaN
# 18                               team              Schottweg            96
# 19                            CLASSIC                Poststr.            5
# 20                               ARAL              Nordstraße           20
# 21                             WIKING             Neustadt 14          NaN
# 22                           Sonstige            Industrieweg           40
# 23                               team         Gather Landstr.        29-31
# 24                                bft        An der Nordstr.             7
# 25                             UNITOL                 Ostring           59
# 26                               ELAN    BUSCH JOHANNSEN STR.            2
# 27                               ARAL  Busch Johannsen Straße            2
# 28                               STAR             Marienallee           60
# 29                              Shell        AN DER B 199 199          NaN
# 30                              Shell     FRIESISCHE STR. 191          NaN
# 31                               team       Scandinavian Park            1
# ...                               ...                     ...          ...
# 15196                            ESSO          BASLER STR. 74
# 15197                             bft           Bregenzerstr.           43
# 15198                            ESSO       MARKGRAFENSTR. 28
# 15199  C+C Oberallgäu Lang-Steudler                    Hofen            18
# 15200                            ARAL     Robert-Bosch-Straße           40
# 15201                      Tankpool24            Bahnhofstr.           110
# 15202                             OMV               Hauptstr.           10
# 15203                             NaN            Mittagstraße            3
# 15204                            ARAL             Illerstraße           12
# 15205      Freie Tankstelle Kaufmarkt   Rudolf-Diesel-Straße             1
# 15206                           BayWa        Hindelanger Str.           26
# 15207                             NaN         Eichendorffstr.        13-15
# 15208                            ESSO       GRUENTENSTR. 32 A
# 15209                             NaN            Grüntenstr.           25a
# 15210                   SB-Tankstelle          Walchenseestr.           34
# 15211                           Shell   OBERSTDORFER STR. 5 A          NaN
# 15212                            AVIA        Sonthofer Straße           31
# 15213                            ARAL             Hauptstraße           20
# 15214                            Agip                Burgstr.           16
# 15215                             OMV         Zugspitzstrasse           42
# 15216                            ESSO         ZUGSPITZSTR. 44
# 15218    82493                   Klais  47.484642  11.237125
# 15219    87538                 Fischen  47.461820  10.267960
# 15220    82481              Mittenwald  47.444924  11.263304
# 15221    87538      Fischen/Langenwang  47.432429  10.269833
# 15222    87561              OBERSTDORF  47.415369  10.275212
# 15223    87561              Oberstdorf  47.412920  10.275360
# 15224    82481              MITTENWALD  47.399570  11.266046
# 15225    82481              MITTENWALD  47.399458  11.265886
#
# [14961 rows x 9 columns]

# %%
gas_stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15226 entries, 0 to 15225
# Data columns (total 9 columns):
# id              15226 non-null int64
# name            15221 non-null object
# brand           14662 non-null object
# street          15218 non-null object
# house_number    11623 non-null object
# zip_code        15222 non-null object
# city            15223 non-null object
# latitude        15226 non-null float64
# longitude       15226 non-null float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 1.0+ MB

# %%
prices_station1 = load_historic_prices(gas_station_id=1)
prices_station1.head()
gas_stations.head()
# Out:
#    id                      name       brand           street house_number  \
# 0   1           star Tankstelle        STAR  Listlandstrasse           16
# 1   2           Esso Tankstelle        ESSO          TRIFT 2
# 2   3               SYLT, TRIFT       Shell          TRIFT 7          NaN
# 3   4          DEXX-Station 188        DEXX        Dorfstr.            19
# 4   5  team Tankautomat Hesbüll  Raiffeisen   Raiffeisenstr.            1
#
#   zip_code        city   latitude  longitude
# 0    25992        List  55.015890   8.429530
# 1    25980  WESTERLAND  54.907468   8.308741
# 2    25980        SYLT  54.904400   8.310700
# 3    25927    Aventoft  54.901300   8.822810
# 4    25927     Hesbüll  54.900900   8.810690

# %%
def calculate_mean_prices(gas_stations_id_list):
    mean_prices = [load_historic_prices(x)[1].mean() for x in gas_stations_id_list]
    return mean_prices

# %%
means = calculate_mean_prices(gas_stations_with_prices_id_list)

# %%
means = np.array(means)
# Out:
# [1348.0250167897918, 1369.7182543238641, 1360.0940660822657, 1379.4158089748869, 1359.6783616319306, 1405.3095746194338, 1399.6295399515739, 1366.9136690647481, 1338.2646794756688, 1379.2197313845545, 1353.8327941771129, 1399.254005470887, 1365.617754283631, 1341.9036635006785, 1366.9328774062817, 1368.6617135630731, 1320.1305830761735, 1369.9580152671756, 1339.9021333885667, 1383.2384987893463, 1371.4885042950984, 1316.0149253731342, 1366.7800248911014, 1385.2827073476876, 1390.8962203715566, 1365.3472882968601, 1338.058562555457, 1339.7093341931325, 1374.7613071276344, 1344.3661210744772, 1357.085411292634, 1330.25, 1401.773682124455, 1371.3816676295012, 1378.5069066555045, 1382.4657149037421, 1351.5281065088757, 1355.3381884387802, 1377.0078125, 1350.1031656592563, 1382.7177707259025, 1385.7302700806733, 1320.2841582266387, 1346.7888499865337, 1336.2330654420207, 1381.4791380585191, 1341.8577754162238, 1378.2470478194784, 1303.4155844155844, 1349.3594276094277, 1370.0992143502747, 1385.2183142130934, 1368.5836193090827, 1372.1082118188795, 1391.5341396800625, 1374.7621914509332, 1314.5555555555557, 1347.9102134784428, 1330.7878308968786, 1366.9146279736797, 1370.1304347826087, 1384.9468096072569, 1384.6859024444693, 1359.5520382094858, 1386.4854505318081, 1370.2023414016769, 1353.4568245125349, 1359.895856662934, 1353.7294955718137, 1386.5244323342415, 1321.176236351959, 1346.6518399428367,

#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/lib/python3.6/site-packages/matplotlib-2.0.2+4101.g94ed61cd7-py3.6-linux-x86_64.egg/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3947                 # must be acceptable as PathCollection facecolors
# -> 3948                 colors = mcolors.to_rgba_array(c)
#    3949             except ValueError:
#
# /usr/lib/python3.6/site-packages/matplotlib-2.0.2+4101.g94ed61cd7-py3.6-linux-x86_64.egg/matplotlib/colors.py in to_rgba_array(c, alpha)
#     239     for i, cc in enumerate(c):
# --> 240         result[i] = to_rgba(cc, alpha)
#     241     return result
#
# /usr/lib/python3.6/site-packages/matplotlib-2.0.2+4101.g94ed61cd7-py3.6-linux-x86_64.egg/matplotlib/colors.py in to_rgba(c, alpha)
#     143     except (KeyError, TypeError):  # Not in cache, or unhashable.
# --> 144         rgba = _to_rgba_no_colorcycle(c, alpha)
#     145         try:
#
# /usr/lib/python3.6/site-packages/matplotlib-2.0.2+4101.g94ed61cd7-py3.6-linux-x86_64.egg/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     194         # Test dimensionality to reject single floats.
# --> 195         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     196     # Return a tuple to prevent the cached value from being modified.
#
# ValueError: Invalid RGBA argument: 1348.0250167897918
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-203-176adf83eb2d> in <module>()
#       6                        c=means,
#       7                        cmap=plt.get_cmap("jet"),
# ----> 8                        colorbar=True
#       9                       )
#      10
#
# /home/rob/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2618                           fontsize=fontsize, colormap=colormap, table=table,
#    2619                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2620                           sort_columns=sort_columns, **kwds)
#    2621     __call__.__doc__ = plot_frame.__doc__
#    2622
#
# /home/rob/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1855                  yerr=yerr, xerr=xerr,
#    1856                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1857                  **kwds)
#    1858
#    1859
#
# /home/rob/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1680         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1681
# -> 1682     plot_obj.generate()
#    1683     plot_obj.draw()
#    1684     return plot_obj.result
#
# /home/rob/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in generate(self)
#     236         self._compute_plot_data()
#     237         self._setup_subplots()
# --> 238         self._make_plot()
#     239         self._add_table()
#     240         self._make_legend()
#
# /home/rob/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in _make_plot(self)
#     830             label = None
#     831         scatter = ax.scatter(data[x].values, data[y].values, c=c_values,
# --> 832                              label=label, cmap=cmap, **self.kwds)
#     833         if cb:
#     834             img = ax.collections[0]
#
# /usr/lib/python3.6/site-packages/matplotlib-2.0.2+4101.g94ed61cd7-py3.6-linux-x86_64.egg/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1800                     warnings.warn(msg % (label_namer, func.__name__),
#    1801                                   RuntimeWarning, stacklevel=2)
# -> 1802             return func(ax, *args, **kwargs)
#    1803         pre_doc = inner.__doc__
#    1804         if pre_doc is None:
#
# /usr/lib/python3.6/site-packages/matplotlib-2.0.2+4101.g94ed61cd7-py3.6-linux-x86_64.egg/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3951                 msg = ("c of shape {0} not acceptable as a color sequence "
#    3952                        "for x with size {1}, y with size {2}")
# -> 3953                 raise ValueError(msg.format(c.shape, x.size, y.size))
#    3954         else:
#    3955             colors = None  # use cmap, norm after collection is created
#
# AttributeError: 'list' object has no attribute 'shape'
